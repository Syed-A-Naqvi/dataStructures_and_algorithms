# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return np.where(x % 2 == 0, (-2)**x, -(-2)**x)

x_values = np.arange(0,10,(1/5))
y_values = f(x_values)

plt.plot(x_values,y_values)
plt.show()
# Out:
# /tmp/ipykernel_11808/2538055677.py:5: RuntimeWarning: invalid value encountered in power
#   return np.where(x % 2 == 0, (-2)**x, -(-2)**x)
